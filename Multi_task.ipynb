# %% [markdown]
# <a href="https://colab.research.google.com/github/MohammAAA/Using-Eye-Gaze-Tracking-And-Imitation-Learning-to-Improve-Autonomous-Driving/blob/master/Multi_task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##########--->> please run me 2 times then continue.
# %%html
<marquee style='width: 90%; color: blue;'><b>The Network is wating for your Contribution <3 !</b></marquee>
<marquee style='width: 30%; color: black;'><b>  please Enjoy your time ;) <3 !</b></marquee>
# Out:
# <marquee style='width: 90%; color: blue;'><b>The Network is wating for your Contribution <3 !</b></marquee>
# <marquee style='width: 30%; color: black;'><b>  please Enjoy your time ;) <3 !</b></marquee>

# %% [markdown]
# # **--->Preparing Data**

# %%
####################--->> Mount Drive & extract data <<---####################

##only need to run this cell 1 time to import and extract dataset , no need to run again even if you restsrted run time

from google.colab import drive
drive.mount('/content/drive')

import zipfile

zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/01.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/02.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/03.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/14.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/20.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/22.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
#zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/37.zip", 'r')
#zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/42.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/44.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/52.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/56.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/nvidia/59.zip", 'r')
zip_ref.extractall("/content/Data_set/Frames/")



zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/01.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/02.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/03.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/14.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/20.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/22.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/42.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/44.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/52.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/56.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")
zip_ref = zipfile.ZipFile("/content/drive/My Drive/GP/our_drEYEve/resized/FOA_NVIDIA/59.zip", 'r')
zip_ref.extractall("/content/Data_set/Gaze/")

zip_ref.close()
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **--->Training & Testing**

# %%
import os
# %tensorflow_version 1.x
import tensorflow as tf
from tensorflow.core.protobuf import saver_pb2
import numpy
import scipy
import matplotlib.pyplot
from PIL import Image
from matplotlib import pyplot as plt
import scipy.misc
import random
from google.colab import output
import time
import numpy as np
import datetime
from openpyxl import load_workbook

#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Preparing Data <<<---####################-------------------------------#
#--------##########################################################################################--------------#
#############################################################################################################



####################--->> directories Paths <<---####################

dir_txt = "/content/drive/My Drive/GP/our_drEYEve/steering_speed_new"
dir_frames = "/content/Data_set/Frames/"
dir_gaze = "/content/Data_set/Gaze"
LOGDIR = '/content/drive/My Drive/multi' #dir to save the output trained model weigths and logs


####################--->> Hyper Parameters & Control <<---####################

dataset_portion =1 # 0.8 for 80% of the dataset (total =82,500 frame), dec. to make sure every thing is working fine then inc. it again to 1

train_test_ratio = 0.8 # 0.7 for Train==> 70%  & Test==> 30%

visualization = 0 #choose the number of video you want to visualize the predicted steering angle on from (0 to 10)

epochs = 50

batch_size = 128

learning_rate = 0.000005 #try not to change this(عشان هتزعل)

L2NormConst = 0.0001*0.5

dropout_keep_prob = 0.8

log_flag = 1  # True for logging this run  training info into the team global DataBase  

random.seed(5)


####################--->> Comment <<---####################

#please write a comment here to be saved in drive to remeber that training for future resutks comparison
comment=" dec L2norm and increasing the epochs training on the whole dataset with frames only  "

#please write your Name
name="MULTI_new_TASK_Abdel karim"

####################--->> Loading Data <<---####################

loc_frames = []
loc_gaze = []
S_angle = []
speed=[]


txt_files = [f for f in os.listdir(dir_txt) if not f.startswith('.')]
#print(len(txt_files))

for i in range(len(txt_files)):
  with open(dir_txt+"/"+txt_files[i]) as f:
    for line in f:

        # Saving the location of each image
        loc_frames.append(dir_frames+"/" +(txt_files[i][0:2])+"/" + line.split()[0])
        

        # Saving the location of each gaze map
        loc_gaze.append(dir_gaze+"/" +(txt_files[i][0:2])+"/" + line.split()[0])
        
        # Saving the steering angles
        S_angle.append(float(line.split()[1])/527) # /800 to normalize for better and faster training

        # Saving the speed
        speed.append(float(line.split()[2]))
        

num_images=len(speed) #get number of images


####################--->> randomly shuffle arrayes for better training <<---####################

loc_frames_testing = loc_frames#[visualization*7500:(visualization*7500)+7499]#save the array unshuffled for the final testing output
loc_gaze_testing=loc_gaze
S_angle_testing = S_angle#[visualization*7500:(visualization*7500)+7499] #same ;)

c = list(zip(loc_frames,loc_gaze, S_angle,speed))
random.shuffle(c)
loc_frames,loc_gaze, S_angle,speed = zip(*c)

print("number of loaded frames : "+str(num_images))


####################--->> Creating arrays <<---####################

xs = [] #final input frames "locations" to the network
gs = [] #Gazemaps "locations"
ys = [] #final label input to the network
Sd = [] #speed

T_Loss = [] #Training loss array
V_Loss = [] #Validation loss array



# points to the end of the last batch
train_batch_pointer = 0
val_batch_pointer = 0


####################--->> read Data <<---####################

xs = loc_frames
ys = S_angle
gs = loc_gaze #not used (yet <3)
Ss = speed #not used (yet <3)



    

####################--->> Train and test ratios <<---####################

train_xs = xs[:int(len(xs) * train_test_ratio)]
train_gs = gs[:int(len(gs) * train_test_ratio)]
train_ys = ys[:int(len(xs) * train_test_ratio)]

val_xs = xs[-int(len(xs) * (1-train_test_ratio)):]
val_gs = gs[-int(len(gs) * (1-train_test_ratio)):]
val_ys = ys[-int(len(xs) * (1-train_test_ratio)):]

num_images=num_images*dataset_portion
num_train_images = len(train_xs)
num_val_images = len(val_xs)


####################--->> LoadTrainBatch & LoadValBatch functions <<---####################

def LoadTrainBatch(batch_size):
    # Train batch pointer allows we use subsequent ahead images for train 
    # Rather than using random images from train data as we train the model 
    # on batches of data rather thatn whole data at each epoch
    global train_batch_pointer
    x_out = []
    g_out = []
    y_out = []
    for i in range(0, batch_size):
        #r = time.time()
        #print(time.time() - r) # testing time
        #Resizing and Converting image in ideal form to train
        x_out.append(numpy.array(Image.fromarray(matplotlib.pyplot.imread(train_xs[(train_batch_pointer + i) % num_train_images])).resize([ 200,66]))/ 255.0)
        g_out.append(numpy.array(Image.fromarray(matplotlib.pyplot.imread(train_gs[(train_batch_pointer + i) % num_train_images])).resize([ 200,66]))/ 255.0)
        y_out.append([train_ys[(train_batch_pointer + i) % num_train_images]])
        #print(time.time() - r) # testing time

    train_batch_pointer += batch_size
    return x_out,g_out, y_out

def LoadValBatch(batch_size):
    global val_batch_pointer
    x_out = []
    g_out = []
    y_out = []
    for i in range(0, batch_size):
        x_out.append(numpy.array(Image.fromarray(matplotlib.pyplot.imread(val_xs[(val_batch_pointer + i) % num_val_images])).resize([200, 66]))/ 255.0)
        g_out.append(numpy.array(Image.fromarray(matplotlib.pyplot.imread(val_gs[(val_batch_pointer + i) % num_val_images])).resize([200, 66]))/ 255.0)
        y_out.append([val_ys[(val_batch_pointer + i) % num_val_images]])
    val_batch_pointer += batch_size
    return x_out,g_out, y_out




#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Model architicture <<<---####################---------------------------#
#--------##########################################################################################--------------#
#############################################################################################################



with tf.device('/device:GPU:0'): #to use GPU
  


  def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)##0.1
    return tf.Variable(initial)

  def bias_variable(shape):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial)

  def conv2d(x, W, stride,padding='VALID'):
    yarb=tf.nn.conv2d(x, W, strides=[1, stride, stride, 1], padding=padding)
    return tf.reshape(yarb,tf.shape(yarb))

  x = tf.placeholder(tf.float32, shape=[batch_size, 66, 200, 3])
  g = tf.placeholder(tf.float32, shape=[batch_size, 66, 200])
  gg=tf.reshape(g,[batch_size,66,200,1])
  y_ = tf.placeholder(tf.float32, shape=[batch_size, 1])
  

  x_image = x
  

  ############################################################################################--Added resizing attention layers
  #input =tf.image.resize(x_image,[32,32 ])
  classes = 3
  img_size = 512
  keep_prob = tf.placeholder(tf.float32)

  
  #train=(keep_prob!=1.0)
  train=True

  def create_weights(shape):
    initial = tf.truncated_normal(shape, stddev=0.06)##0.1
    return tf.Variable(initial)

  def create_biases(shape):
    initial = tf.constant(0.06, shape=shape)
    return tf.Variable(initial)
  """
  def create_weights(shape):
      return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

  def create_biases  (size):
      return tf.Variable(tf.constant(0.05, shape=[size]))
  """    

  def conv_layer(input3, num_input_channels, conv_filter_size, num_filters, padding='SAME', relu=True):

      weights = create_weights(shape=[conv_filter_size, conv_filter_size, num_input_channels, num_filters])
      biases = create_biases(num_filters)
      
      layer = tf.nn.conv2d(input3, filter=weights, strides=[1, 1, 1, 1], padding=padding)
      layer += biases

      if relu:
          layer = tf.nn.relu(layer)

      layer = tf.reshape(layer,tf.shape(layer))    
      return layer

  def pool_layer(input2, padding='SAME'):
      return tf.nn.max_pool(value=input2,
                            ksize = [1, 2, 2, 1],
                            strides=[1, 2, 2, 1],
                            padding=padding)
      


  def un_conv(input1, num_input_channels, conv_filter_size, num_filters, feature_map_size, train=True, padding='SAME',relu=True):


      weights = create_weights(shape=[conv_filter_size, conv_filter_size, num_filters, num_input_channels])
      biases = create_biases(num_filters)
      if train:
          batch_size_0 = 1
      else:
          batch_size_0 = 1

          
      layer = tf.nn.conv2d_transpose(value=input1, filter=weights,output_shape=[ batch_size ,feature_map_size, feature_map_size, num_filters],
                                     strides=[1, 2, 2, 1],
                                     padding=padding)
      layer =layer+ biases
      layer = tf.nn.relu(layer)

      layer = tf.reshape(layer,[batch_size, feature_map_size, feature_map_size, num_filters])
      return layer

  #--------##########################################################################################--------------#
  #-----------------####################--->>> U-Net <<<---####################---------------------------#
  #--------##########################################################################################--------------#

    # train is used for un_conv, to determine the batch size
  """"
  zz=tf.image.resize(x_image,[img_size,img_size])

  conv1 = conv_layer(zz, 3, 3, 64)
  conv2 = conv_layer(conv1, 64, 3, 64)
  pool2 = pool_layer(conv2)
  conv3 = conv_layer(pool2, 64, 3, 128)
  conv4 = conv_layer(conv3, 128, 3, 128)
  pool4 = pool_layer(conv4)
  conv5 = conv_layer(pool4, 128, 3, 256)
  conv6 = conv_layer(conv5, 256, 3, 256)
  pool6 = pool_layer(conv6)
  conv7 = conv_layer(pool6, 256, 3, 512)
  conv8 = conv_layer(conv7, 512, 3, 512)
  pool8 = pool_layer(conv8)
  conv9 = conv_layer(pool8, 512, 3, 1024)                               
  conv10 = conv_layer(conv9, 1024, 3, 1024)                             
  conv11 = un_conv(conv10, 1024, 2, 512, img_size // 8, train)          
  merge11 = tf.concat(values=[conv8, conv11], axis = -1)
  conv12 = conv_layer(merge11, 1024, 3, 512)




  #conv8 = conv_layer(tf.image.resize(x_image,[200,200 ]), 3, 3, 3) #198*3
  #pool8 = pool_layer(conv8)##############################################
  #conv9 = conv_layer(pool8, 3, 3, 6)                             
  #conv10 = conv_layer(conv9, 6, 3,6) 
  #conv10 = tf.reshape(conv10, [batch_size,100,100,6])
   
  


  #zz=tf.image.resize(x_image,[200,200 ])

  #conv8 = conv_layer(zz, 3, 3, 3)
  #pool8 = pool_layer(conv8)##############################################
  #conv9 = conv_layer(pool8, 3, 3, 6)                               #
  #conv10 = conv_layer(conv9, 6, 3, 6)                             #
  #conv11 = un_conv(conv10, 6, 2, 3, 200, train)          #
  #merge11 = tf.concat(values=[conv8, conv11], axis = -1)#################
  #conv12 = conv_layer(merge11, 6, 3, 3)


  #conv11 = tf.nn.conv2d_transpose(zgz, create_weights(shape=[2,2,3,3]), [batch_size,200,200,3], [1,1, 1, 1], padding='SAME')
  #conv11 = tf.reshape(conv11, [128,200,200,3])
                             
  #conv11 = un_conv(conv10, 6, 2, 3, 200, train)
  #conv11 = tf.reshape(conv11, [128,200,200,3])
  
  #merge11 = tf.concat([conv11, conv11], axis = -1)#################
  #merge11 = tf.reshape(merge11, [128,200,200,6])

  #conv12 = conv_layer(merge11, 6, 3, 3)
  #conv12 = tf.reshape(conv12, [batch_size,200,200,3])


  conv13 = conv_layer(conv12, 512, 3, 512)

  conv14 = un_conv(conv13, 512, 2, 256, img_size // 4, train)
  merge14 = tf.concat([conv6, conv14], axis=-1)

  conv15 = conv_layer(merge14, 512, 3, 256)
  conv16 = conv_layer(conv15, 256, 3, 256)

  conv17 = un_conv(conv16, 256, 2, 128, img_size // 2, train)
  merge17 = tf.concat([conv17, conv4], axis=-1)

  conv18 = conv_layer(merge17, 256, 3, 128)
  conv19 = conv_layer(conv18, 128, 3, 128)

  conv20 = un_conv(conv19, 128, 2, 64, img_size, train)
  merge20 = tf.concat([conv20, conv2], axis=-1)

  conv21 = conv_layer(merge20, 128, 3, 64)
  conv22 = conv_layer(conv21, 64, 3, 64)
  conv23 = conv_layer(conv22, 64, 1, classes)

  h_res =tf.image.resize(conv23,[66,200])
  
  """
  ############################################################################################# pilotnet

  #first convolutional layer
  W_conv1 = weight_variable([5, 5, 3, 24])###200*66
  b_conv1 = bias_variable([24])

  h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1, 2) + b_conv1)###98*31

  #grads = tf.gradients(x_image, h_res)


  #second convolutional layer
  W_conv2 = weight_variable([5, 5, 24, 36])
  b_conv2 = bias_variable([36])

  h_conv2 = tf.nn.relu(conv2d(h_conv1, W_conv2, 2) + b_conv2)###47*14

  #third convolutional layer
  W_conv3 = weight_variable([5, 5, 36, 48])
  b_conv3 = bias_variable([48])

  h_conv3 = tf.nn.relu(conv2d(h_conv2, W_conv3, 2) + b_conv3)###22*5


  ############################################################################################>>>######>>>> gaze branch
  ############################################################################################



  W_unconv1 = create_weights([5, 5, 36, 48])
  b_unconv1 = create_biases([36])
  unconv1 =tf.nn.relu(tf.nn.conv2d_transpose(h_conv3, W_unconv1,[ batch_size ,14, 47, 36], strides=[1, 2, 2, 1],padding='VALID')+b_unconv1)

  W_conv11 = create_weights([5, 5, 36, 36])
  b_conv11 = create_biases([36])
  h_conv11 = tf.nn.relu(conv2d(unconv1, W_conv11, 1,"SAME") + b_conv11)  


  W_unconv2 = create_weights([5, 5, 24, 36])
  b_unconv2 = create_biases([24])
  unconv2 =tf.nn.relu(tf.nn.conv2d_transpose(h_conv11, W_unconv2,[ batch_size ,31, 98, 24], strides=[1, 2, 2, 1],padding='VALID')+b_unconv2)

  W_conv22 = create_weights([5, 5, 24, 24])
  b_conv22 = create_biases([24])
  h_conv22 = tf.nn.relu(conv2d(unconv2, W_conv22, 1,"SAME") + b_conv22)


  W_unconv3 = create_weights([5, 5, 1, 24])
  b_unconv3 = create_biases([1])
  unconv3 =tf.nn.relu(tf.nn.conv2d_transpose(h_conv22, W_unconv3,[ batch_size ,66, 200, 1], strides=[1, 2, 2, 1],padding='VALID')+b_unconv3)

  W_conv33 = create_weights([5, 5, 1, 1])
  b_conv33 = create_biases([1])
  h_conv33 = tf.nn.relu(conv2d(unconv3, W_conv33, 1,"SAME") + b_conv33)


  sig_layer=(h_conv33)

  ########################################################################################################## cont pilot

  #fourth convolutional layer
  W_conv4 = weight_variable([3, 3, 48, 64])
  b_conv4 = bias_variable([64])

  h_conv4 = tf.nn.relu(conv2d(h_conv3, W_conv4, 1) + b_conv4)

  #fifth convolutional layer
  W_conv5 = weight_variable([3, 3, 64, 64])
  b_conv5 = bias_variable([64])

  h_conv5 = tf.nn.relu(conv2d(h_conv4, W_conv5, 1) + b_conv5)

  #FCL 1
  W_fc1 = weight_variable([1152, 1164])
  b_fc1 = bias_variable([1164])

  h_conv5_flat = tf.reshape(h_conv5, [-1, 1152])
  h_fc1 = tf.nn.relu(tf.matmul(h_conv5_flat, W_fc1) + b_fc1)

  keep_prob = tf.placeholder(tf.float32)
  h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

  #FCL 2
  W_fc2 = weight_variable([1164, 100])
  b_fc2 = bias_variable([100])

  h_fc2 = tf.nn.relu(tf.matmul(h_fc1_drop, W_fc2) + b_fc2)

  h_fc2_drop = tf.nn.dropout(h_fc2, keep_prob)

  #FCL 3
  W_fc3 = weight_variable([100, 50])
  b_fc3 = bias_variable([50])

  h_fc3 = tf.nn.relu(tf.matmul(h_fc2_drop, W_fc3) + b_fc3)

  h_fc3_drop = tf.nn.dropout(h_fc3, keep_prob)

  #FCL 3
  W_fc4 = weight_variable([50, 10])
  b_fc4 = bias_variable([10])

  h_fc4 = tf.nn.relu(tf.matmul(h_fc3_drop, W_fc4) + b_fc4)

  h_fc4_drop = tf.nn.dropout(h_fc4, keep_prob)

  #Output
  W_fc5 = weight_variable([10, 1])
  b_fc5 = bias_variable([1])

  #linear
  y =  tf.nn.tanh(tf.matmul(h_fc4_drop, W_fc5) + b_fc5)#scale the atan output





#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Training <<<---####################---------------------------#
#--------##########################################################################################--------------#
#############################################################################################################
"""
####################--->> pretrained model training <<---####################
sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, LOGDIR+"/model.ckpt")
train_vars = tf.trainable_variables()
gaze_l=tf.losses.mean_squared_error(gg, sig_layer)
loss = tf.sqrt( tf.reduce_mean(tf.square(tf.subtract(y_,y))))+( tf.add_n([tf.nn.l2_loss(v) for v in train_vars]) * L2NormConst)+ gaze_l
train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)
sess.run(tf.initialize_all_variables())
saver.restore(sess, LOGDIR+"/model.ckpt")
"""
####################--->> new model training <<---####################
sess = tf.InteractiveSession()
train_vars = tf.trainable_variables()
gaze_l=tf.losses.mean_squared_error(gg, sig_layer)
#gaze_l=tf.reduce_mean(tf.square(tf.subtract(gg, sig_layer)))
pilot_loss=tf.sqrt( tf.reduce_mean(tf.square(tf.subtract(y_,y))))

loss =pilot_loss+( tf.add_n([tf.nn.l2_loss(v) for v in train_vars]) * L2NormConst)+ gaze_l
train_step = tf.train.AdamOptimizer(learning_rate).minimize(loss)
sess.run(tf.initialize_all_variables())



# create a summary to monitor cost tensor
tf.summary.scalar("loss", loss)

# merge all summaries into a single op
merged_summary_op =  tf.summary.merge_all()

saver = tf.train.Saver(write_version = saver_pb2.SaverDef.V1)

# op to write logs to Tensorboard
logs_path = './logs'
#summary_writer = tf.summary.FileWriter(logs_path, graph=tf.get_default_graph())


r=time.time()
# train over the dataset about 30 times
for epoch in range(epochs):
  t=time.time()
  for i in range(int(num_images/batch_size)):

       
    xs,gs, ys = LoadTrainBatch(batch_size)
    
    train_step.run(feed_dict={x: xs,g:gs, y_: ys, keep_prob:dropout_keep_prob})
     
    
    if i % 100 == 0:

      loss_value_train= loss.eval(feed_dict={x:xs,g:gs, y_: ys, keep_prob: 1.0})

      xs,gs, ys = LoadValBatch(batch_size)
      

      loss_value= loss.eval(feed_dict={x:xs,g:gs, y_: ys, keep_prob: 1.0})



      output.clear()  
      T_Loss.append(loss_value_train)
      V_Loss.append(loss_value) 


      #print("Model saved in file: %s" % filename)

      x1=time.time()-r
      hoba=(x1/((i+1)+int(num_images/batch_size)*epoch))
      x_time= ( hoba * (int(num_images/batch_size)-i ))  +  (hoba*int(num_images/batch_size)*(epochs-epoch)) #remaining time calculation
      fig = plt.figure(figsize=(5, 5), dpi= 80, facecolor='w', edgecolor='k')

      plt.plot(V_Loss, 'r')
      plt.plot(T_Loss, 'b')



      plt.legend(['V_Loss', 'T_Loss',])
      plt.show()
      
      
      plt.imshow(xs[0])
      plt.show()

      plt.imshow( gg.eval(feed_dict={x:xs,g:gs ,y_: ys, keep_prob: 1.0})[0,:,:,0])
      plt.show()

      plt.imshow( sig_layer.eval(feed_dict={x:xs,g:gs ,y_: ys, keep_prob: 1.0})[0,:,:,0])
      plt.show()

      

      
      #read data.txt
      xs = val_xs
      ys = val_ys
      S_angle_pridected=[]

      #get number of images
      num_images = len(xs)
      val=num_images
      i = num_images 
      image=np.zeros((batch_size,66,200,3))
      deg=np.zeros(batch_size)
      ####################--->> first loop for RMSE Calculation <<---####################
      for i in range (0,num_images-batch_size,batch_size):
          
          for j in range (batch_size):
            image[j,:,:,:]=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[j+i])).resize([ 200,66]))/ 255.0)

          deg=(( y.eval(feed_dict={x:  image, keep_prob: 1.0})))
          S_angle_pridected=np.append(S_angle_pridected,deg)

      RMSE =np.sqrt( np.square(np.subtract(ys[0:len(S_angle_pridected)],S_angle_pridected[0:len(ys)])).mean())


      print("*******************************************************************")
      print(" ")
      print(" ")
      print("==================>  RMSE = "+str(RMSE))
      print(" ")
      print(" ")
      print("*******************************************************************")



      print("Epoch: %d, Step: %d, V-Loss: %g, T-Loss: %g , Remaining time: %g ,"  % (epoch, epoch * batch_size + i, loss_value,loss_value_train,x_time/60.0 ))
    
       

    # write logs at every iteration
    
   # summary = merged_summary_op.eval(feed_dict={x:xs, g:gs,y_: ys,keep_prob: 1.0})
   # summary_writer.add_summary(summary, epoch * num_images/batch_size + i)

    if i % batch_size == 0:
      if not os.path.exists(LOGDIR):
        os.makedirs(LOGDIR)
      checkpoint_path = os.path.join(LOGDIR, "model.ckpt")
      #
      filename = saver.save(sess, checkpoint_path)

tr_time=time.time() - r

print(" ")
print("####################--->>> Training Done <<<---####################")
print(" ")
print("total training time : "+str(tr_time/60)+" min.") # training time
print(" ")
time.sleep(3)
print("####################--->>> Starting Testing <<<---####################")
print(" ")


#saving the trained model & images
dttime=str(datetime.datetime.now())
tf.gfile.MkDir("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime)

checkpoint_path = os.path.join(LOGDIR, "/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/model.ckpt")
filename = saver.save(sess, checkpoint_path)

fig = plt.figure()
plt.plot(V_Loss, 'r')
plt.plot(T_Loss, 'b')
plt.legend(['V_Loss', 'T_Loss'])
plt.savefig("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/Train_Test_Loss.png")


#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Testing <<<---####################---------------------------#
#--------##########################################################################################--------------#
#############################################################################################################



sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, LOGDIR+"/model.ckpt")


#read data.txt
xs = val_xs
ys = val_ys
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 
image=np.zeros((batch_size,66,200,3))
deg=np.zeros(batch_size)
####################--->> first loop for RMSE Calculation <<---####################
for i in range (0,num_images-batch_size,batch_size):
    
    for j in range (batch_size):
      image[j,:,:,:]=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[j+i])).resize([ 200,66]))/ 255.0)

    deg=(( y.eval(feed_dict={x:  image, keep_prob: 1.0})))
    S_angle_pridected=np.append(S_angle_pridected,deg)

RMSE =np.sqrt( np.square(np.subtract(ys[0:len(S_angle_pridected)],S_angle_pridected[0:len(ys)])).mean())


print("*******************************************************************")
print(" ")
print(" ")
print("==================>  RMSE = "+str(RMSE))
print(" ")
print(" ")
print("*******************************************************************")


#read data.txt
xs = loc_frames_testing
ys = S_angle_testing
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 
#loc_frames_testing

####################--->> second loop for Visualization <<---####################

for i in range (0,num_images-batch_size,batch_size):
    for j in range (batch_size):
      
      image[j,:,:,:]=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[j+(i)])).resize([ 200,66]))/ 255.0)

    deg=(( y.eval(feed_dict={x:  image, keep_prob: 1.0})))
    S_angle_pridected=np.append(S_angle_pridected,deg)


####################--->> plot the result <<---####################

fig = plt.figure(figsize=(385, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(S_angle_testing[0:len(S_angle_pridected)], 'r')
plt.plot(S_angle_pridected[0:len(ys)], 'b')
plt.legend(['actual angle', 'predicted angle'])
plt.savefig("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/Steering_angle.png")


#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Logging Results to DataBase <<<---####################----------------------#
#--------##########################################################################################--------------#
#############################################################################################################


####################--->> please dont modify any thing in this section ! <<---####################

if(log_flag==1):
  # Start by opening the spreadsheet and selecting the main sheet
  workbook = load_workbook(filename="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Data_Base.xlsx")
  sheet = workbook.active

  
  flg=True 
  i=1
  while (flg):
    
    #go through the rows untile an empty one is found
    if(sheet.cell(row=i, column=1).value):
      i=i+1
      
    else:
      sheet.cell(row=i, column=1).value = str(name)
      sheet.cell(row=i, column=2).value = str( datetime.datetime.now())
      sheet.cell(row=i, column=3).value = str(RMSE)
      sheet.cell(row=i, column=4).value = str(tr_time/60)
      sheet.cell(row=i, column=5).value = str(dataset_portion)
      sheet.cell(row=i, column=6).value = str(loss_value_train )
      sheet.cell(row=i, column=7).value = str(loss_value)    
      sheet.cell(row=i, column=8).value = str(train_test_ratio)
      sheet.cell(row=i, column=9).value = str(epochs)
      sheet.cell(row=i, column=10).value = str(batch_size)
      sheet.cell(row=i, column=11).value = str(learning_rate)
      sheet.cell(row=i, column=12).value = str(L2NormConst)
      sheet.cell(row=i, column=13).value = str(dropout_keep_prob)
      sheet.cell(row=i, column=14).value = str(comment)

      flg=False 



  # Save the spreadsheet
  workbook.save(filename="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Data_Base.xlsx")

print(" ")
time.sleep(1)
print("####################--->>> Data logging Done <<<---####################")
print("**********good job "+ name+ " ! **********" )
# Out:
# *******************************************************************
#
#
# ==================>  RMSE = 0.09607402583165878
#
#
# *******************************************************************
# Epoch: 34, Step: 20608, V-Loss: 0.365844, T-Loss: 0.362665 , Remaining time: 16.6517 ,
# WARNING:tensorflow:*******************************************************
# WARNING:tensorflow:TensorFlow's V1 checkpoint format has been deprecated.
# WARNING:tensorflow:Consider switching to the more efficient V2 format:
# WARNING:tensorflow:   `tf.train.Saver(write_version=tf.train.SaverDef.V2)`
# WARNING:tensorflow:now on by default.
# WARNING:tensorflow:*******************************************************

# %%
print("number of parameters =",np.sum([np.product([xi.value for xi in x.get_shape()]) for x in tf.trainable_variables()]))
# Out:
# number of parameters = 1707858

# %%
#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Testing <<<---####################---------------------------#
#--------##########################################################################################--------------#
#############################################################################################################



sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, LOGDIR+"/model.ckpt")


#read data.txt
xs = val_xs
ys = val_ys
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 

####################--->> first loop for RMSE Calculation <<---####################
for i in range (0,num_images):
    
    image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)

    
    deg=( y.eval(feed_dict={x: np.repeat(image[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0][0])
    S_angle_pridected.append(deg)

RMSE =np.sqrt( np.square(np.subtract(ys,S_angle_pridected)).mean())


print("*******************************************************************")
print(" ")
print(" ")
print("==================>  RMSE = "+str(RMSE))
print(" ")
print(" ")
print("*******************************************************************")


#read data.txt
xs = loc_frames_testing
ys = S_angle_testing
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 
loc_frames_testing

####################--->> second loop for Visualization <<---####################

for i in range (0,num_images):
    
    image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)


    deg=( y.eval(feed_dict={x: np.repeat(image[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0][0])
    S_angle_pridected.append(deg)


####################--->> plot the result <<---####################

fig = plt.figure(figsize=(385, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(ys, 'r')
plt.plot(S_angle_pridected, 'b')
plt.legend(['actual angle', 'predicted angle'])
plt.savefig("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/Steering_angle.png")


#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Logging Results to DataBase <<<---####################----------------------#
#--------##########################################################################################--------------#
#############################################################################################################


####################--->> please dont modify any thing in this section ! <<---####################

if(log_flag==1):
  # Start by opening the spreadsheet and selecting the main sheet
  workbook = load_workbook(filename="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Data_Base.xlsx")
  sheet = workbook.active

  
  flg=True 
  i=1
  while (flg):
    
    #go through the rows untile an empty one is found
    if(sheet.cell(row=i, column=1).value):
      i=i+1
      
    else:
      sheet.cell(row=i, column=1).value = str(name)
      sheet.cell(row=i, column=2).value = str( datetime.datetime.now())
      sheet.cell(row=i, column=3).value = str(RMSE)
      sheet.cell(row=i, column=4).value = str(tr_time/60)
      sheet.cell(row=i, column=5).value = str(dataset_portion)
      sheet.cell(row=i, column=6).value = str(loss_value_train )
      sheet.cell(row=i, column=7).value = str(loss_value)    
      sheet.cell(row=i, column=8).value = str(train_test_ratio)
      sheet.cell(row=i, column=9).value = str(epochs)
      sheet.cell(row=i, column=10).value = str(batch_size)
      sheet.cell(row=i, column=11).value = str(learning_rate)
      sheet.cell(row=i, column=12).value = str(L2NormConst)
      sheet.cell(row=i, column=13).value = str(dropout_keep_prob)
      sheet.cell(row=i, column=14).value = str(comment)

      flg=False 



  # Save the spreadsheet
  workbook.save(filename="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Data_Base.xlsx")

print(" ")
time.sleep(1)
print("####################--->>> Data logging Done <<<---####################")
print("**********good job "+ name+ " ! **********" )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-f760b8434a86> in <module>()
#       3
#       4 sess = tf.InteractiveSession()
# ----> 5 saver = tf.train.Saver()
#       6 saver.restore(sess, LOGDIR+"/model.ckpt")
#       7
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py in __init__(self, var_list, reshape, sharded, max_to_keep, keep_checkpoint_every_n_hours, name, restore_sequentially, saver_def, builder, defer_build, allow_empty, write_version, pad_step_number, save_relative_paths, filename)
#     826           time.time() + self._keep_checkpoint_every_n_hours * 3600)
#     827     elif not defer_build:
# --> 828       self.build()
#     829     if self.saver_def:
#     830       self._check_saver_def()
#
# /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py in build(self)
# ...

# %%
      d=( sig_layer.eval(feed_dict={x:xs2,g:gs2 ,y_: ys2, keep_prob: 1.0})[0,:,:,0])
      plt.imshow(d)
      plt.show()
      print(d.max())
      print(d.mean())


      f=( gg.eval(feed_dict={x:xs2,g:gs2 ,y_: ys2, keep_prob: 1.0})[0,:,:,0])
      plt.imshow(f)
      plt.show()
      #print(W_conv3.eval()[0])
      print(f.max())
      print(f.mean())
# Out:
# 0.62391084
# 0.05498173
# 0.98039216
# 0.055487823

# %%
x=np.softmax(0.5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-69356b35c2d8> in <module>()
# ----> 1 x=np.softmax(0.5)
#
# AttributeError: module 'numpy' has no attribute 'softmax'

# %%
import tensorflow as tf

sess = tf.Session()
batch_size = 128
output_shape = [batch_size, 8, 8, 128]
strides = [1, 1, 1, 1]

l = tf.constant(0.1, shape=[128, 66, 200, 3])
#w = tf.constant(0.1, shape=[7, 7, 128, 4])

def create_weights(shape):
     return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

output = tf.constant(0.1, shape=[128,66,200,3])
w  = create_weights(shape=[2,2,3,3])
expected_l = tf.nn.conv2d(output, w, strides=strides, padding='SAME')
#print (expected_l.get_shape())

h1 = tf.nn.conv2d_transpose(l, w, output_shape=[128,66,200,3], strides=[1, 1, 1, 1], padding='SAME')
sess.run(tf.initialize_all_variables())
print (sess.run(expected_l).shape)

print (sess.run(h1).shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-faeae9e3d3ee> in <module>()
#       1 import tensorflow as tf
#       2
# ----> 3 sess = tf.Session()
#       4 batch_size = 128
#       5 output_shape = [batch_size, 8, 8, 128]
#
# AttributeError: module 'tensorflow' has no attribute 'Session'
#
# ---------------------------------------------------------------------------
# NOTE: Current TensorFlow version is 2.2.0-rc2. To use TF 1.x instead,
# restart your runtime (Ctrl+M .) and run "%tensorflow_version 1.x" before
# you run "import tensorflow".
# ---------------------------------------------------------------------------

# %%
x=np.zeros((128,200,200,3))
print(x.shape)

zgz=tf.image.resize(x,[200,200 ])
print(zgz.shape)

# %%
      #plt.imshow(( input.eval(feed_dict={x: [imager],  keep_prob: 1.0}))[0])
      #plt.show()
      print(merge11.shape)
      #print(input.shape)
      #("?"!=str(x_image[:,0,0,0].shape[0]))

# %%
      plt.imshow(( h_res.eval(feed_dict={x: np.repeat(imager[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0,:,:,0]))
      plt.show()
      plt.imshow(( h_res.eval(feed_dict={x: np.repeat(imager[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0,:,:,1]))
      plt.show()
      plt.imshow(( h_res.eval(feed_dict={x: np.repeat(imager[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0,:,:,2]))
      plt.show()

      plt.imshow(( h_res.eval(feed_dict={x: np.repeat(imager[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0]*10))
      plt.show()

      print()

# %%
print(int(x_image[:,0,0,0].shape[0]))

# %%
x=("?"!=str(x_image[:,0,0,0].shape[0]))
print(x)

# %%
x_image1=tf.reshape(x_image,[-1,66,200,1])
  #x_image=tf.reshape(x_image,[-1,66,200,3])

  W_res = weight_variable([5, 5, 1, 1])
  b_res = bias_variable([1])

  h_res

# %% [markdown]
# # **---> More Testing**

# %%
x=[1,2,3,4]
y=tf.reshape(x,[-1,1])
x=np.array(x)
print(y.shape)

# %%
print(h_res.shape)
print(x_image.shape)
print(h_res1.shape)
print(x_image1.shape)

# %%
x_image1=tf.reshape(x_image,[-1,66,200,1])


  h_res

# %%
import os 
import tensorflow as tf
from subprocess import call

####################--->> control panel <<---####################

# enter the path of the trained model from results database to load
trained_model_path="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/Abdel karim_2020-03-05 21:15:47.423387"

#choose the number of video you want to visualize the predicted steering angle on from (0 to 10)
visualization = 6

####################--->> Loading Data <<---####################

dir_txt = "/content/drive/My Drive/GP/our_drEYEve/steering_speed"
dir_frames = "/content/Data_set/Frames/"

loc_frames = []
loc_gaze = []
S_angle = []
speed=[]


txt_files = [f for f in os.listdir(dir_txt) if not f.startswith('.')]
#print(len(txt_files))

for i in range(len(txt_files)):
  with open(dir_txt+"/"+txt_files[i]) as f:
    for line in f:

        # Saving the location of each image
        loc_frames.append(dir_frames+"/" +(txt_files[i][0:2])+"/" + line.split()[0])
        


        
        # Saving the steering angles
        S_angle.append(float(line.split()[1])/800) # /800 to normalize for better and faster training


        

num_images=len(speed) #get number of images


####################--->> Load testing video <<---####################

loc_frames_testing = loc_frames[visualization*7500:(visualization*7500)+7499]#save the array unshuffled for the final testing output
S_angle_testing = S_angle[visualization*7500:(visualization*7500)+7499] #same ;)


sess = tf.InteractiveSession()
#Xc = tf.Variable(initial_value='fake_variable')
saver = tf.train.Saver()
saver.restore(sess, trained_model_path+"/model.ckpt")


#read data.txt
xs = val_xs
ys = val_ys
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 

####################--->> first loop for RMSE Calculation <<---####################
"""for i in range (0,num_images):
    
    image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)

    deg=( y.eval(feed_dict={x: [image], keep_prob: 1.0})[0][0])
    S_angle_pridected.append(deg)

RMSE =np.sqrt( np.square(np.subtract(ys,S_angle_pridected)).mean())


print("*******************************************************************")
print(" ")
print(" ")
print("==================>  RMSE = "+str(RMSE))
print(" ")
print(" ")
print("*******************************************************************")
"""

#read data.txt
xs = loc_frames_testing
ys = S_angle_testing
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 
loc_frames_testing

####################--->> second loop for Visualization <<---####################

for i in range (0,num_images):
    
    image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)

    deg=( y.eval(feed_dict={x: [image], keep_prob: 1.0})[0][0])
    S_angle_pridected.append(deg)


####################--->> plot the result <<---####################

fig = plt.figure(figsize=(35, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(ys, 'r')
plt.plot(S_angle_pridected, 'b')
plt.legend(['actual angle', 'predicted angle'])
plt.savefig("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/Steering_angle.png")

# %%
####################--->> test the prediction on a random image from dataset <<---####################

i=random.randint(0,len(xs)-1)
image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)
deg=( y.eval(feed_dict={x: [image], keep_prob: 1.0})[0][0])

print("actual steering angle = "+str(ys[i]*800)+"       predicted steering angle = "+str(deg*800))
print(" ")
see=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66])))
plt.imshow(see)
#h_conv2

# %%
##################################middle image testing
i=random.randint(0,len(xs)-1)
image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)
deg=( h_conv1.eval(feed_dict={x: [image], keep_prob: 1.0})[0][0])
print(deg.shape)
plt.imshow(deg)
"""
print("actual steering angle = "+str(ys[i]*800)+"       predicted steering angle = "+str(deg*800))
print(" ")
see=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66])))
plt.imshow(see)
#h_conv2
"""

# %%
txt_files = [f for f in os.listdir(dir_txt) if not f.startswith('.')]
#print(len(txt_files))
S_angle=[]
for i in range(len(txt_files)):
  with open(dir_txt+"/"+txt_files[i]) as f:
    for line in f:

        
        # Saving the steering angles
        S_angle.append(float(line.split()[1])/800) # /800 to normalize for better and faster training


print(len(S_angle))

# %%
S_angle=np.array(S_angle)
print(S_angle.max()*800)

# %% [markdown]
# # **---> Early stopping**

# %%
tr_time=time.time() - r

print(" ")
print("####################--->>> Training Done <<<---####################")
print(" ")
print("total training time : "+str(tr_time/60)+" min.") # training time
print(" ")
time.sleep(3)
print("####################--->>> Starting Testing <<<---####################")
print(" ")


#saving the trained model & images
dttime=str(datetime.datetime.now())
tf.gfile.MkDir("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime)

checkpoint_path = os.path.join(LOGDIR, "/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/model.ckpt")
filename = saver.save(sess, checkpoint_path)

fig = plt.figure()
plt.plot(V_Loss, 'r')
plt.plot(T_Loss, 'b')
plt.legend(['V_Loss', 'T_Loss'])
plt.savefig("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/Train_Test_Loss.png")


#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Testing <<<---####################---------------------------#
#--------##########################################################################################--------------#
#############################################################################################################



sess = tf.InteractiveSession()
saver = tf.train.Saver()
saver.restore(sess, "save/model.ckpt")


#read data.txt
xs = val_xs
ys = val_ys
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 

####################--->> first loop for RMSE Calculation <<---####################
for i in range (0,num_images):
    
    image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)
    
    deg=( y.eval(feed_dict={x: np.repeat(image[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0][0])
    S_angle_pridected.append(deg)

RMSE =np.sqrt( np.square(np.subtract(ys,S_angle_pridected)).mean())


print("*******************************************************************")
print(" ")
print(" ")
print("==================>  RMSE = "+str(RMSE))
print(" ")
print(" ")
print("*******************************************************************")


#read data.txt
xs = loc_frames_testing
ys = S_angle_testing
S_angle_pridected=[]

#get number of images
num_images = len(xs)
val=num_images
i = num_images 
loc_frames_testing

####################--->> second loop for Visualization <<---####################

for i in range (0,num_images):
    
    image=(np.array(Image.fromarray(matplotlib.pyplot.imread(xs[i])).resize([ 200,66]))/ 255.0)

    deg=( y.eval(feed_dict={x: np.repeat(image[np.newaxis, :,:,: ], batch_size, axis=0), keep_prob: 1.0})[0][0])
    S_angle_pridected.append(deg)


####################--->> plot the result <<---####################

fig = plt.figure(figsize=(385, 5), dpi= 80, facecolor='w', edgecolor='k')
plt.plot(ys, 'r')
plt.plot(S_angle_pridected, 'b')
plt.legend(['actual angle', 'predicted angle'])
plt.savefig("/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Results_files/"+(name)+"_"+dttime+"/Steering_angle.png")


#############################################################################################################
#--------##########################################################################################--------------#
#-----------------####################--->>> Logging Results to DataBase <<<---####################----------------------#
#--------##########################################################################################--------------#
#############################################################################################################


####################--->> please dont modify any thing in this section ! <<---####################

if(log_flag==1):
  # Start by opening the spreadsheet and selecting the main sheet
  workbook = load_workbook(filename="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Data_Base.xlsx")
  sheet = workbook.active

  
  flg=True 
  i=1
  while (flg):
    
    #go through the rows untile an empty one is found
    if(sheet.cell(row=i, column=1).value):
      i=i+1
      
    else:
      sheet.cell(row=i, column=1).value = str(name)
      sheet.cell(row=i, column=2).value = str( datetime.datetime.now())
      sheet.cell(row=i, column=3).value = str(RMSE)
      sheet.cell(row=i, column=4).value = str(tr_time/60)
      sheet.cell(row=i, column=5).value = str(dataset_portion)
      sheet.cell(row=i, column=6).value = str(loss_value_train )
      sheet.cell(row=i, column=7).value = str(loss_value)    
      sheet.cell(row=i, column=8).value = str(train_test_ratio)
      sheet.cell(row=i, column=9).value = str(epochs)
      sheet.cell(row=i, column=10).value = str(batch_size)
      sheet.cell(row=i, column=11).value = str(learning_rate)
      sheet.cell(row=i, column=12).value = str(L2NormConst)
      sheet.cell(row=i, column=13).value = str(dropout_keep_prob)
      sheet.cell(row=i, column=14).value = str(comment)

      flg=False 



  # Save the spreadsheet
  workbook.save(filename="/content/drive/My Drive/GP/our_drEYEve/Results_DataBase/Data_Base.xlsx")

print(" ")
time.sleep(1)
print("####################--->>> Data logging Done <<<---####################")
print("**********good job "+ name+ " ! **********" )

# %%
import numpy as np
import tensorflow as tf

import datetime

batch_size = 2
classes = 1
img_size = 512


def create_weights(shape):
    return tf.Variable(tf.truncated_normal(shape, stddev=0.05))

def create_biases(size):
    return tf.Variable(tf.constant(0.05, shape=[size]))

def conv_layer(input, num_input_channels, conv_filter_size, num_filters, padding='SAME', relu=True):
    weights = create_weights(shape=[conv_filter_size, conv_filter_size, num_input_channels, num_filters])
    biases = create_biases(num_filters)
    layer = tf.nn.conv2d(input=input, filter=weights, strides=[1, 1, 1, 1], padding=padding)
    layer += biases

    if relu:
        layer = tf.nn.relu(layer)
    return layer

def pool_layer(input, padding='SAME'):
    return tf.nn.max_pool(value=input,
                          ksize = [1, 2, 2, 1],
                          strides=[1, 2, 2, 1],
                          padding=padding)

def un_conv(input, num_input_channels, conv_filter_size, num_filters, feature_map_size, train=True, padding='SAME',relu=True):


    weights = create_weights(shape=[conv_filter_size, conv_filter_size, num_filters, num_input_channels])
    biases = create_biases(num_filters)
    if train:
        batch_size_0 = batch_size
    else:
        batch_size_0 = 1
    layer = tf.nn.conv2d_transpose(value=input, filter=weights,
                                   output_shape=[batch_size_0, feature_map_size, feature_map_size, num_filters],
                                   strides=[1, 2, 2, 1],
                                   padding=padding)
    layer += biases

    if relu:
        layer = tf.nn.relu(layer)
    return layer


def create_unet(input, train=True):

    # train is used for un_conv, to determine the batch size

    conv1 = conv_layer(input, 3, 3, 64)
    conv2 = conv_layer(conv1, 64, 3, 64)
    pool2 = pool_layer(conv2)
    conv3 = conv_layer(pool2, 64, 3, 128)
    conv4 = conv_layer(conv3, 128, 3, 128)
    pool4 = pool_layer(conv4)
    conv5 = conv_layer(pool4, 128, 3, 256)
    conv6 = conv_layer(conv5, 256, 3, 256)
    pool6 = pool_layer(conv6)
    conv7 = conv_layer(pool6, 256, 3, 512)
    conv8 = conv_layer(conv7, 512, 3, 512)
    pool8 = pool_layer(conv8)

    conv9 = conv_layer(pool8, 512, 3, 1024)
    conv10 = conv_layer(conv9, 1024, 3, 1024)

    conv11 = un_conv(conv10, 1024, 2, 512, img_size // 8, train)
    merge11 = tf.concat(values=[conv8, conv11], axis = -1)

    conv12 = conv_layer(merge11, 1024, 3, 512)
    conv13 = conv_layer(conv12, 512, 3, 512)

    conv14 = un_conv(conv13, 512, 2, 256, img_size // 4, train)
    merge14 = tf.concat([conv6, conv14], axis=-1)

    conv15 = conv_layer(merge14, 512, 3, 256)
    conv16 = conv_layer(conv15, 256, 3, 256)

    conv17 = un_conv(conv16, 256, 2, 128, img_size // 2, train)
    merge17 = tf.concat([conv17, conv4], axis=-1)

    conv18 = conv_layer(merge17, 256, 3, 128)
    conv19 = conv_layer(conv18, 128, 3, 128)

    conv20 = un_conv(conv19, 128, 2, 64, img_size, train)
    merge20 = tf.concat([conv20, conv2], axis=-1)

    conv21 = conv_layer(merge20, 128, 3, 64)
    conv22 = conv_layer(conv21, 64, 3, 64)
    conv23 = conv_layer(conv22, 64, 1, classes)

    return conv23

if __name__ == '__main__':
    oldtime = datetime.datetime.now()
    for i in range(16):
        input = tf.constant(0.6, shape=[1, 512, 512, 3])
        y = create_unet(input, train=False)
        print(y)
    newtime = datetime.datetime.now()
